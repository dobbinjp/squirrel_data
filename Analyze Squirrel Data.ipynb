# %% [markdown]
# Lab setup - follow these steps to successfully complete the lab:
# 1. Please download each of the 4 csv files in this github repo: https://github.com/dobbinjp/squirrel_data/tree/main
# 2. Enable DBFS browsing in Advanced Settings (click on your user icon, select "settings" then "advanced" and search for "DBFS")
# 3. Go to your catalog and click on DBFS then "Upload"
# 4. Specify a folder ("squirrel" or something similar) and browse to upload the 4 files
# 5. Copy the folder location to your clipboard and paste it in the text box at the top of this notebook ("folder_loc")
# 6. Specify a value for "dbname" and run this notebook ("Run All" button should work)

# %%
# copy the location of the folder with your squirrel data (from DBFS)
# set the database_name and squirrel_folder variables to the current parameter text
squirrel_folder = dbutils.widgets.get("folder_loc")
database_name = dbutils.widgets.get("dbname")

# %%
# store list of files in a variable
squirrel_datafiles = dbutils.fs.ls(squirrel_folder)

# %%
# print the paths of each file in the DBFS squirrel data folder
for s in squirrel_datafiles:
  # dbutils.fs.rm(s.path) # this line can be uncommented if you need to clear the DBFS folder
  print(s)
# Out:
# FileInfo(path='dbfs:/FileStore/squirrel123/park_data.csv', name='park_data.csv', size=4204, modificationTime=1744145433000)
# FileInfo(path='dbfs:/FileStore/squirrel123/squirrel_data_2018.csv', name='squirrel_data_2018.csv', size=720561, modificationTime=1744145433000)
# FileInfo(path='dbfs:/FileStore/squirrel123/squirrel_data_2020.csv', name='squirrel_data_2020.csv', size=59517, modificationTime=1744145432000)
# FileInfo(path='dbfs:/FileStore/squirrel123/stories.csv', name='stories.csv', size=7995, modificationTime=1744145432000)

# %%
# create the database if it does not exist already, then set it to the current database
spark.sql(f"create database if not exists {database_name};")
spark.sql(f"use {database_name};")
# Out:
# DataFrame[]

# %%
# loop through all data files, read them and make a table of each
for i in squirrel_datafiles:
  print(i.name)
  df = spark.read.format("csv").options(inferSchema=True, header=True).load(i.path)
  spark.sql(f"drop table if exists {i.name.replace('.csv','')};")
  df.write.format("delta").mode("overwrite").saveAsTable(i.name.replace('.csv',''))
# Out:
# park_data.csv
# squirrel_data_2018.csv
# squirrel_data_2020.csv
# stories.csv

# %%
# %sql
--enable change data feed on the table we will be manipulating
ALTER TABLE squirrel_data_2020 SET TBLPROPERTIES (delta.enableChangeDataFeed = true);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
  update squirrel_data_2020
  set Longitude = -1 * Longitude
  where Longitude > 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql

delete from squirrel_data_2020 
where Longitude is null and Latitude is null;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>92</td></tr></tbody></table></div>

# %%
# %sql

insert into
  squirrel_data_2020
select
  null as AreaName,
  null as AreaID,
  null as ParkName,
  null as ParkID,
  UniqueSquirrelID as SquirrelID,
  PrimaryFurColor,
  HighlightFurColor as HighlightsinFurColor,
  Colornotes as ColorNotes,
  Location,
  AboveGroundSighterMeasurement as HeightAboveGroundFeet,
  null as SpecificLocation,
  OtherActivities as Activities,
  OtherInteractions as InteractionswithHumans,
  null as Notes,
  Y as Latitude,
  X as Longitude
from
  squirrel_data_2018;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3023</td><td>3023</td></tr></tbody></table></div>

# %%
# %sql
select * from squirrel_data_2020;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AreaName</th><th>AreaID</th><th>ParkName</th><th>ParkID</th><th>SquirrelID</th><th>PrimaryFurColor</th><th>HighlightsinFurColor</th><th>ColorNotes</th><th>Location</th><th>HeightAboveGroundFeet</th><th>SpecificLocation</th><th>Activities</th><th>InteractionswithHumans</th><th>Notes</th><th>Latitude</th><th>Longitude</th></tr></thead><tbody><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>37F-PM-1014-03</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.79408239</td><td>-73.95613449</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>21B-AM-1019-04</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.78378252</td><td>-73.96885747</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>11B-PM-1014-08</td><td>Gray</td><td>null</td><td>null</td><td>Above Ground</td><td>10</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.77553362</td><td>-73.97428115</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>32E-PM-1017-14</td><td>Gray</td><td>null</td><td>Nothing selected as Primary. Gray selected as Highlights. Made executive adjustments.</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.79031289</td><td>-73.95964139</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>13E-AM-1017-05</td><td>Gray</td><td>Cinnamon</td><td>null</td><td>Above Ground</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.77621269</td><td>-73.97026765</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>11H-AM-1010-03</td><td>Cinnamon</td><td>White</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.77259088</td><td>-73.96836135</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>36H-AM-1010-02</td><td>Gray</td><td>null</td><td>just outside hectare</td><td>Ground Plane</td><td>FALSE</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.79318117</td><td>-73.95412018</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>33F-AM-1008-02</td><td>Gray</td><td>null</td><td>null</td><td>Ground Plane</td><td>FALSE</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.79173678</td><td>-73.95826943</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>21C-PM-1006-01</td><td>Gray</td><td>null</td><td>null</td><td>Ground Plane</td><td>FALSE</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.78297239</td><td>-73.9674286</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>11D-AM-1010-03</td><td>Gray</td><td>Cinnamon</td><td>null</td><td>Above Ground</td><td>30</td><td>null</td><td>grooming</td><td>null</td><td>null</td><td>40.77428796</td><td>-73.97225002</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>20B-PM-1013-05</td><td>Gray</td><td>White</td><td>null</td><td>Ground Plane</td><td>FALSE</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.78235077</td><td>-73.96950635</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>22F-PM-1014-06</td><td>Gray</td><td>null</td><td>null</td><td>Ground Plane</td><td>FALSE</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.78203098</td><td>-73.96400328</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>36I-PM-1007-01</td><td>Gray</td><td>Cinnamon</td><td>null</td><td>Ground Plane</td><td>FALSE</td><td>null</td><td>null</td><td>null</td><td>null</td><td>40.79196697</td><td>-73.95321705</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>5C-PM-1010-09</td><td>Cinnamon</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>FALSE</td><td>null</td><td>null</td><td>null</td><td>nu ...

# %%
# %sql
describe history squirrel_data_2020;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>4</td><td>2025-04-08T21:55:13Z</td><td>1392220080137065</td><td>jimmy.dobbins@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(3703707432810307)</td><td>0408-204609-c3omxhhv</td><td>3</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3023, numOutputBytes -> 89822)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>3</td><td>2025-04-08T21:55:10Z</td><td>1392220080137065</td><td>jimmy.dobbins@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(isnull(Longitude#21494) AND isnull(Latitude#21493))"])</td><td>null</td><td>List(3703707432810307)</td><td>0408-204609-c3omxhhv</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 20776, numCopiedRows -> 341, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 1, executionTimeMs -> 1645, numDeletionVectorsUpdated -> 0, numDeletedRows -> 92, scanTimeMs -> 679, numAddedFiles -> 1, numAddedBytes -> 19718, rewriteTimeMs -> 966)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>2</td><td>2025-04-08T21:55:05Z</td><td>1392220080137065</td><td>jimmy.dobbins@gmail.com</td><td>UPDATE</td><td>Map(predicate -> ["(Longitude#20478 > 0.0)"])</td><td>null</td><td>List(3703707432810307)</td><td>0408-204609-c3omxhhv</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 20549, numCopiedRows -> 432, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 1, executionTimeMs -> 2900, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1382, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 20776, rewriteTimeMs -> 1517)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>1</td><td>2025-04-08T21:55:00Z</td><td>1392220080137065</td><td>jimmy.dobbins@gmail.com</td><td>SET TBLPROPERTIES</td><td>Map(properties -> {"delta.enableChangeDataFeed":"true"})</td><td>null</td><td>List(3703707432810307)</td><td>0408-204609-c3omxhhv</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr><tr><td>0</td><td>2025-04-08T21:54:54Z</td><td>1392220080137065</td><td>jimmy.dobbins@gmail.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {}, statsOnLoad -> false)</td><td>null</td><td>List(3703707432810307)</td><td>0408-204609-c3omxhhv</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 1, numOutputRows -> 433, numOutputBytes -> 20549)</td><td>null</td><td>Databricks-Runtime/15.4.x-scala2.12</td></tr></tbody></table></div>

# %%
# %sql
select count(*) from squirrel_data_2020 version as of 4;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>3364</td></tr></tbody></table></div>

# %%
# %sql

select * from table_changes('squirrel_data_2020', 3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AreaName</th><th>AreaID</th><th>ParkName</th><th>ParkID</th><th>SquirrelID</th><th>PrimaryFurColor</th><th>HighlightsinFurColor</th><th>ColorNotes</th><th>Location</th><th>HeightAboveGroundFeet</th><th>SpecificLocation</th><th>Activities</th><th>InteractionswithHumans</th><th>Notes</th><th>Latitude</th><th>Longitude</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>UPPER MANHATTAN</td><td>A</td><td>Highbridge Park</td><td>3</td><td>A-03-13</td><td>Gray</td><td>Cinnamon</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Running</td><td>null</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-01</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Running, up tree</td><td>Runs From</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-02</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Running, up tree</td><td>Runs From</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-03</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Running, up tree</td><td>Indifferent</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-04</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Chasing</td><td>Indifferent</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-05</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Chasing</td><td>null</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-06</td><td>Gray</td><td>Gray</td><td>null</td><td>Above Ground</td><td>15</td><td>null</td><td>Sitting on branch</td><td>Indifferent</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-07</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Running, up tree</td><td>Indifferent</td><td>Forever wild section</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-08</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Eating</td><td>Indifferent</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memorial)</td><td>5</td><td>A-05-09</td><td>Gray</td><td>Gray</td><td>null</td><td>Ground Plane</td><td>null</td><td>null</td><td>Eating</td><td>Indifferent</td><td>null</td><td>null</td><td>null</td><td>delete</td><td>3</td><td>2025-04-08T21:55:10Z</td></tr><tr><td>UPPER MANHATTAN</td><td>A</td><td>Riverside Park (Section Near Grant Memori ...
